# %% [markdown]
# # ***Model 2: Deeper CNN (Conv-Conv-Pool ×2) using CIFAR-10 DataSet***

# %% [markdown]
# Applying deeper architecture using the same dataset, same optimizer, same learning rate, same batch size.

# %%
# %cd /content

import os

if not os.path.exists("/content/cifar10-cnn-classification-project"):
    # !git clone https://github.com/karimamzghi/cifar10-cnn-classification-project.git

# %cd /content/cifar10-cnn-classification-project

from google.colab import drive
drive.mount("/content/drive")
# Out:
# /content
# /content/cifar10-cnn-classification-project
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Import numpy lib
import importlib

import numpy as np

# Imports matptotlib lib
import matplotlib.pyplot as plt

# Imports tensorflow.Keras lib
import keras as keras
from keras import layers
from keras.backend import clear_session
from keras.optimizers import SGD

# Imports seaborn lib
import seaborn as sns

# Imports sklearn lib
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import confusion_matrix

import importlib

from src import config

import src.training.trainer as trainer
import src.training.evaluator as evaluator
import src.data_loader as data_loader

importlib.reload(trainer)
importlib.reload(evaluator)
importlib.reload(data_loader)
importlib.reload(config)

# Imports custom files aka config, experiment files, etc
from src.training.trainer import compile_model, train_model, save_model
from src.training.evaluator import (
    evaluate_model,
    get_predictions,
    calculate_precision_recall,
    save_confusion_matrix
)
from src.data_loader import load_data
from src.experiment_tracker import save_experiment_results

# %%
MODEL_ID = 2
MODEL_NAME = "deeper_cnn"

# %%
# Load the data fromm cache using the load_data function from data_loader.py
x_train, y_train, x_val, y_val, x_test, y_test = load_data()
# Out:
# Loading cached data from Google Drive: /content/drive/MyDrive/cifar10_cache

# %%
import os

print(os.listdir("/content/drive/MyDrive"))
# Out:
# ['Parku Contract', 'Steuerberater', 'postIdent_i1.pdf', '20170315221513142.pdf', 'Capture 2017-03-06 at 21.36.13.png', 'Archive.zip', 'wohnung.gsheet', 'IMG_0001.JPG', 'IMG_0002.JPG', 'IMG_0003.JPG', 'IMG_0006.JPG', 'IMG_0007.JPG', 'IMG_0008.JPG', 'IMG_0009.JPG', 'IMG_0010.JPG', 'IMG_0011.JPG', 'IMG_0012.JPG', 'IMG_0013.JPG', 'IMG_0014.JPG', 'IMG_0015.JPG', 'IMG_0016.JPG', 'IMG_0017.JPG', 'IMG_0018.JPG', 'IMG_0020.JPG', 'IMG_0021.JPG', 'IMG_0022.JPG', 'IMG_0023.JPG', 'IMG_0024.JPG', 'IMG_0025.JPG', 'IMG_0026.JPG', 'IMG_0027.JPG', 'IMG_0029.JPG', 'IMG_0030.JPG', 'IMG_0031.JPG', 'IMG_0033.JPG', 'IMG_0035.JPG', 'IMG_0036.JPG', 'IMG_0038.JPG', 'IMG_0039.JPG', 'IMG_0040.JPG', 'IMG_0041.JPG', 'IMG_0042.JPG', 'IMG_0043.JPG', 'IMG_0044.JPG', 'IMG_0045.JPG', 'IMG_0046.JPG', 'IMG_0047.JPG', 'IMG_0049.JPG', 'IMG_0050.JPG', 'IMG_0051.JPG', 'IMG_0052.JPG', 'IMG_0053.JPG', 'IMG_0054.JPG', 'IMG_0055.JPG', 'IMG_0057.JPG', 'IMG_0058.JPG', 'IMG_0059.JPG', 'IMG_0060.JPG', 'IMG_0061.JPG', 'IMG_0062.JPG', 'IMG_0063.JPG', 'IMG_0064.JPG', 'IMG_0066.JPG', 'IMG_0067.JPG', 'IMG_0068.JPG
JPG', 'IMG_0247.JPG', 'IMG_0248.JPG', 'IMG_0249.JPG', 'IMG_0250.JPG', 'IMG_0251.JPG', 'IMG_0252.JPG', 'IMG_0253.JPG', 'IMG_0254.JPG', 'IMG_0255.JPG', 'IMG_0257.JPG', 'IMG_0258.JPG', 'IMG_0259.JPG', 'IMG_0260.JPG', 'IMG_0261.JPG', 'IMG_0262.JPG', 'IMG_0263.JPG', 'IMG_0265.JPG', 'IMG_0266.JPG', 'IMG_0267.JPG', 'IMG_0268.JPG', 'IMG_0269.JPG', 'IMG_0270.JPG', 'IMG_0271.JPG', 'IMG_0272.JPG', 'IMG_0273.JPG', 'IMG_0274.JPG', 'IMG_0275.JPG', 'IMG_0276.JPG', 'IMG_0277.JPG', 'IMG_0278.JPG', 'IMG_0279.JPG', 'IMG_0280.JPG', 'IMG_0281.JPG', 'IMG_0282.JPG', 'IMG_0283.JPG', 'IMG_0285.JPG', 'IMG_0286.JPG', 'IMG_0287.JPG', 'IMG_0289.JPG', 'IMG_0291.JPG', 'IMG_0292.JPG', 'IMG_0293.JPG', 'IMG_0294.JPG', 'IMG_0295.JPG', 'IMG_0297.JPG', 'IMG_0298.JPG', 'IMG_0299.JPG', 'IMG_0300.JPG', 'IMG_0301.JPG', 'IMG_0302.JPG', 'IMG_0303.JPG', 'IMG_0304.JPG', 'IMG_0305.JPG', 'IMG_0306.JPG', 'IMG_0308.JPG', 'IMG_0309.JPG', 'IMG_0310.JPG', 'IMG_031 ...

# %%
print(os.listdir("/content/drive/MyDrive/cifar10_cache"))
# Out:
# ['x_train.npy', 'y_train.npy', 'x_val.npy', 'y_val.npy', 'x_test.npy', 'y_test.npy']

# %%
# Clear any previous TensorFlow models from memory as TensorFlow can accumulate unnecessary objects in memory,
# especially if we are creating many models while tuning hyperparameters.
clear_session()

# %%
# Build Model 2: Deeper CNN.

deeper_model = keras.Sequential(
    [
        keras.Input(shape=config.INPUT_SHAPE),

        layers.Conv2D(32, kernel_size=(3, 3), activation="relu"),
        layers.Conv2D(32, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),

        layers.Conv2D(64, kernel_size=(3, 3), activation="relu"),
        layers.Conv2D(64, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),

        layers.Flatten(),

        layers.Dense(64, activation="relu"),
        layers.Dense(config.NUM_CLASSES, activation="softmax"),
    ],
    
    name="deeper_cnn"
)

deeper_model.summary()
# Out:
# Model: "deeper_cnn"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 30, 30, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 28, 28, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 12, 12, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 10, 10, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1600)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │       102,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 168,682 (658.91 KB)
#  Trainable params: 168,682 (658.91 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the model using categorical_crossentropy loss, SGD optimizer and use 'accuracy' as the metric
optimizer = keras.optimizers.SGD(
    learning_rate=config.LEARNING_RATE
)

deeper_model = compile_model(
    model=deeper_model,
    optimizer=optimizer,
    loss=config.CATEGORICAL_CROSSENTROPY,
    metrics=[config.ACCURACY]
)

# %%
# Train the model using the train_model function from trainer.py
history, train_time = train_model(
    model=deeper_model,
    x_train=x_train,
    y_train=y_train,
    x_val=x_val,
    y_val=y_val,
    batch_size=config.BATCH_SIZE,
    epochs=config.EPOCHS
)
# Out:
# Epoch 1/20
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.1154 - loss: 2.3007 - val_accuracy: 0.1150 - val_loss: 2.2985
# Epoch 2/20
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.1136 - loss: 2.2961 - val_accuracy: 0.1177 - val_loss: 2.2939
# Epoch 3/20
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.1184 - loss: 2.2905 - val_accuracy: 0.1233 - val_loss: 2.2870
# Epoch 4/20
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.1248 - loss: 2.2817 - val_accuracy: 0.1307 - val_loss: 2.2759
# Epoch 5/20
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.1383 - loss: 2.2663 - val_accuracy: 0.1509 - val_loss: 2.2549
# Epoch 6/20
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.1628 - loss: 2.2357 - val_accuracy: 0.1808 - val_loss: 2.2117
# Epoch 7/20
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.1994 - loss: 2.1724 - val_accuracy: 0.2097 - val_loss: 2.1261
# Epoch 8/20
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.2384 - loss: 2.0737 - val_accuracy: 0.2642 - val_loss: 2.0317
# Epoch 9/20
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.2752 - loss: 2.0056 - val_accuracy: 0.2724 - val_loss: 2.0098
# Epoch 10/20
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.2890 - loss: 1.9746 - val_accuracy: 0.2920 - val_loss: 1.9761
# Epoch 11/20
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.2993 - loss: 1.9505 - val_accuracy: 0.3032 - val_loss: 1.9444
# Epoch 12/20
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.3100 - loss: 1.9264 - val_accuracy: 0.3049 - val_loss: 1.9230
# Epoch 13/20
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.3215 - loss: 1.9032 - val_accuracy: 0.3243 - val_loss: 1.8928
# Epoch 14/20
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.3337 - loss: 1.8781 - val_accuracy: 0.3363 - val_loss: 1.8626
# Epoch 15/20
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.3437 - loss: 1.8500 - val_accuracy: 0.3470 - val_loss: 1.8435
# Epoch 16/20
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.3522 - loss: 1.8212 - val_accuracy: 0.3531 - val_loss: 1.8323
# Epoch 17/20
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.3650 - loss: 1.7884 - val_accuracy: 0.3657 - val_loss: 1.7887
# Epoch 18/20
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.3770 - loss: 1.7550 - val_accuracy: 0.3838 - val_loss: 1.7500
# Epoch 19/20
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.3873 - loss: 1.7224 - val_accuracy: 0.3649 - val_loss: 1.7680
# Epoch 20/20
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.3980 - loss: 1.6923 - val_accuracy: 0.3886 - val_loss: 1.7182

# %%
# Sanity check: confirm we're using the new 70/15/15 split (15% of 60,000 = 9,000) and not the original Keras default test set (10,000)
print("x_test shape:", x_test.shape)
print("Expected: ~9000 (15% of 60000)")

# Evaluate the baseline model on the held-out test set 
test_loss, test_accuracy = evaluate_model(
    model=deeper_model,
    x_test=x_test,
    y_test=y_test
)

test_labels, test_predictions, y_pred_probs = get_predictions(
    model=deeper_model,
    x_test=x_test,
    y_test=y_test
)

precision, recall = calculate_precision_recall(
    test_labels=test_labels,
    test_predictions=test_predictions
)

print("Test accuracy:", test_accuracy)
print("Precision:", precision)
print("Recall:", recall)
# Out:
# x_test shape: (9000, 32, 32, 3)
# Expected: ~9000 (15% of 60000)
# x_test shape: (9000, 32, 32, 3)
# Expected: ~9000 (15% of 60000)
#
# Test loss: 2.0026187896728516
# Test accuracy: 0.3233333230018616
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Precision: 0.4198  Recall: 0.3233
# Test accuracy: 0.3233333230018616
# Precision: 0.4197837741211236
# Recall: 0.3233333333333333

# %%
# Save the model to a file under the models directory with a name that includes the model ID and model name
model_path = save_model(
    model=deeper_model,
    model_name=f"model_{MODEL_ID}_{MODEL_NAME}",
    models_dir=config.MODELS_DIR
)
# Out:
# Model saved to: ./models/model_2_deeper_cnn.keras

# %%
# Save the confusion matrix to a file under the confusion_matrices directory with a name that includes the model ID and model name
confusion_matrix_path = (
    f"{config.CONFUSION_DIR}/model_{MODEL_ID}_{MODEL_NAME}_confusion_matrix.png"
)

save_confusion_matrix(
    test_labels=test_labels,
    test_predictions=test_predictions,
    output_path=confusion_matrix_path,
    title=f"Model {MODEL_ID} - Baseline CNN Confusion Matrix on CIFAR-10 Test Set"
)
# Out:
# './results/confusion_matrices/model_2_deeper_cnn_confusion_matrix.png'

# %%
experiment = {
    "model_id": MODEL_ID,
    "model_name": MODEL_NAME,
    "architecture": "Conv2D(32) + Conv2D(32) + MaxPool + Conv2D(64) + Conv2D(64) + MaxPool + Dense(64)",
    "optimizer": "SGD",
    "learning_rate": config.LEARNING_RATE,
    "batch_size": config.BATCH_SIZE,
    "epochs": len(history.history["accuracy"]),
    "train_accuracy": history.history["accuracy"][-1],
    "validation_accuracy": history.history["val_accuracy"][-1],
    "test_accuracy": test_accuracy,
    "precision": precision,
    "recall": recall,
    "train_loss": history.history["loss"][-1],
    "validation_loss": history.history["val_loss"][-1],
    "test_loss": test_loss,
    "train_time_seconds": train_time,
    "model_path": model_path,
    "confusion_matrix_path": confusion_matrix_path,
    "notes": "Model 2 tests whether deeper Conv-Conv-Pool blocks improve performance over baseline"
}

results_df = save_experiment_results(
    experiment,
    config.RESULTS_PATH
)

results_df
# Out:
#    model_id    model_name                                       architecture  \
# 0         1  baseline_cnn  Conv2D(32) + MaxPool + Conv2D(64) + MaxPool + ...
# 1         2    deeper_cnn  Conv2D(32) + Conv2D(32) + MaxPool + Conv2D(64)...
#
#   augmentation transfer_learning optimizer  learning_rate  batch_size  epochs  \
# 0           No                No       SGD          0.001          64      20
# 1          NaN               NaN       SGD          0.001          64      20
#
#    train_accuracy  ...  test_accuracy  train_loss  validation_loss  test_loss  \
# 0        0.379071  ...       0.371000    1.782614          1.77950   1.782990
# 1        0.397976  ...       0.323333    1.692275          1.71816   2.002619
#
#                           model_path  \
# 0          models/baseline_cnn.keras
# 1  ./models/model_2_deeper_cnn.keras
#
#                                confusion_matrix_path  \
# 0  results/confusion_matrices/model_1_baseline_cn...
# 1  ./results/confusion_matrices/model_2_deeper_cn...
#
#                                                notes precision    recall  \
# 0  Baseline CNN trained from scratch using SGD op...       NaN       NaN
# 1  Model 2 tests whether deeper Conv-Conv-Pool bl...  0.419784  0.323333
#
#    train_time_seconds
# 0                 NaN
# 1                80.3
#
# [2 rows x 21 columns]

# %%
# draw a plot of the training and validation accuracy over epochs
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Save the plot of the training and validation accuracy over epochs
os.makedirs(config.PLOTS_DIR, exist_ok=True)
accuracy_curves_path = (f"{config.PLOTS_DIR}/Model_{MODEL_ID}_{MODEL_NAME}_accuracy_curves.png")
plt.savefig(accuracy_curves_path, bbox_inches="tight")
plt.show()

print("Accuracy curves saved to:", accuracy_curves_path)
# Out:
# Accuracy curves saved to: ./results/plots/Model_2_deeper_cnn_accuracy_curves.png

# %%
# Draw the training and validation loss over epochs
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')    
plt.ylabel('Loss')
plt.legend()

# Save the plot of the training and validation loss over epochs
os.makedirs(config.PLOTS_DIR, exist_ok=True)
loss_curves_path = (f"{config.PLOTS_DIR}/Model_{MODEL_ID}_{MODEL_NAME}_loss_curves.png")
plt.savefig(loss_curves_path, bbox_inches="tight")
plt.show()

print("Loss curves saved to:", loss_curves_path)
# Out:
# Loss curves saved to: ./results/plots/Model_2_deeper_cnn_loss_curves.png

# %%
# Deploy the model using Gradio interface
# %cd /content/cifar10-cnn-classification-project
# !PYTHONPATH=/content/cifar10-cnn-classification-project python deployment/app.py
