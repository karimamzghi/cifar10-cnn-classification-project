# %% [markdown]
# # ***Model 6: Augmented CNN Model using CIFAR-10 DataSet***

# %% [markdown]
# Build CNN Model with Data Augmentation. Reused Model and add data augmentation at the beginning of the model and maintain Batch Normalization and Dropout.

# %%
# %cd /content

import os

if not os.path.exists("/content/cifar10-cnn-classification-project"):
    # !git clone https://github.com/karimamzghi/cifar10-cnn-classification-project.git

# %cd /content/cifar10-cnn-classification-project

from google.colab import drive
drive.mount("/content/drive")
# Out:
# /content
# /content/cifar10-cnn-classification-project
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
MODEL_ID = 6
MODEL_NAME = "augmented_cnn"

# %%
# Import numpy lib
import importlib

import numpy as np

# Imports matptotlib lib
import matplotlib.pyplot as plt

# Imports tensorflow.Keras lib
import keras as keras
from keras import layers
from keras.backend import clear_session
from keras.optimizers import SGD

# Imports seaborn lib
import seaborn as sns

# Imports sklearn lib
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import confusion_matrix

import importlib

from src import config

import src.training.trainer as trainer
import src.training.evaluator as evaluator
import src.data_loader as data_loader

importlib.reload(trainer)
importlib.reload(evaluator)
importlib.reload(data_loader)
importlib.reload(config)

# Imports custom files aka config, experiment files, etc
from src.training.trainer import compile_model, train_model, save_model
from src.training.evaluator import (
    evaluate_model,
    get_predictions,
    calculate_precision_recall,
    save_confusion_matrix
)
from src.data_loader import load_data
from src.experiment_tracker import save_experiment_results    
from src.training.model_builder import build_dropout_cnn, build_batchnorm_cnn, build_augmented_cnn

# %%
# Load the data fromm cache using the load_data function from data_loader.py
from src.data_loader import load_data

x_train, y_train, x_val, y_val, x_test, y_test = load_data()
# Out:
# Loading cached data from Google Drive: /content/drive/MyDrive/cifar10_cache

# %%
# Clear any previous TensorFlow models from memory as TensorFlow can accumulate unnecessary objects in memory,
# especially if we are creating many models while tuning hyperparameters.
clear_session()

# %%
# compile the model using the compile_model function from trainer.py
augmented_model = build_augmented_cnn()
augmented_model.summary()
# Out:
# Model: "augmented_cnn"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ data_augmentation (Sequential)  │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 30, 30, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 30, 30, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 28, 28, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 28, 28, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 12, 12, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 12, 12, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 10, 10, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 10, 10, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1600)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │       102,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 169,706 (662.91 KB)
#  Trainable params: 169,194 (660.91 KB)
#  Non-trainable params: 512 (2.00 KB)

# %%
# appluy the Adam optimizer to the model using the compile_model function from trainer.py
adam_optimizer = keras.optimizers.Adam(
    learning_rate=config.LEARNING_RATE,
)

augmented_model = compile_model(
    model=augmented_model,
    optimizer=adam_optimizer,
    loss=config.CATEGORICAL_CROSSENTROPY,
    metrics=[config.ACCURACY]
)

# %%
# Train the model using the train_model function from trainer.py
history, train_time = train_model(
    model=augmented_model,
    x_train=x_train,
    y_train=y_train,
    x_val=x_val,
    y_val=y_val,
    batch_size=config.BATCH_SIZE,
    epochs=config.EPOCHS
)
# Out:
# Epoch 1/20
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 27s 29ms/step - accuracy: 0.3891 - loss: 1.7626 - val_accuracy: 0.5322 - val_loss: 1.3303
# Epoch 2/20
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 20s 31ms/step - accuracy: 0.5247 - loss: 1.3372 - val_accuracy: 0.5199 - val_loss: 1.4109
# Epoch 3/20
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 20s 31ms/step - accuracy: 0.5784 - loss: 1.1958 - val_accuracy: 0.6276 - val_loss: 1.0636
# Epoch 4/20
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 19s 28ms/step - accuracy: 0.6101 - loss: 1.1133 - val_accuracy: 0.6432 - val_loss: 1.0390
# Epoch 5/20
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 21s 32ms/step - accuracy: 0.6387 - loss: 1.0449 - val_accuracy: 0.6430 - val_loss: 1.0424
# Epoch 6/20
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 20s 30ms/step - accuracy: 0.6549 - loss: 0.9996 - val_accuracy: 0.6422 - val_loss: 1.0429
# Epoch 7/20
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 21s 32ms/step - accuracy: 0.6699 - loss: 0.9622 - val_accuracy: 0.7000 - val_loss: 0.8655
# Epoch 8/20
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 20s 30ms/step - accuracy: 0.6818 - loss: 0.9302 - val_accuracy: 0.6517 - val_loss: 1.0432
# Epoch 9/20
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 14s 22ms/step - accuracy: 0.6935 - loss: 0.8992 - val_accuracy: 0.7070 - val_loss: 0.8665
# Epoch 10/20
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 21s 32ms/step - accuracy: 0.7008 - loss: 0.8740 - val_accuracy: 0.6773 - val_loss: 0.9425
# Epoch 11/20
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 19s 29ms/step - accuracy: 0.7075 - loss: 0.8550 - val_accuracy: 0.6921 - val_loss: 0.9083
# Epoch 12/20
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 22s 33ms/step - accuracy: 0.7154 - loss: 0.8361 - val_accuracy: 0.6980 - val_loss: 0.8626
# Epoch 13/20
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 151s 201ms/step - accuracy: 0.7157 - loss: 0.8289 - val_accuracy: 0.6759 - val_loss: 0.9526
# Epoch 14/20
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 0.7272 - loss: 0.8069

# %%
# Sanity check: confirm we're using the new 70/15/15 split (15% of 60,000 = 9,000) and not the original Keras default test set (10,000)
print("x_test shape:", x_test.shape)
print("Expected: ~9000 (15% of 60000)")

# Evaluate the baseline model on the held-out test set 
test_loss, test_accuracy = evaluate_model(
    model=augmented_model,
    x_test=x_test,
    y_test=y_test
)

test_labels, test_predictions, y_pred_probs = get_predictions(
    model=augmented_model,
    x_test=x_test,
    y_test=y_test
)

precision, recall = calculate_precision_recall(
    test_labels=test_labels,
    test_predictions=test_predictions
)

print("Test accuracy:", test_accuracy)
print("Precision:", precision)
print("Recall:", recall)
# Out:
# x_test shape: (9000, 32, 32, 3)
# Expected: ~9000 (15% of 60000)
# x_test shape: (9000, 32, 32, 3)
# Expected: ~9000 (15% of 60000)
#
# Test loss: 0.7652157545089722
# Test accuracy: 0.7429999709129333
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Precision: 0.7446  Recall: 0.7430
# Test accuracy: 0.7429999709129333
# Precision: 0.7445605434593215
# Recall: 0.743

# %%
model_path = save_model(
    model=augmented_model,
    model_name=f"model_{MODEL_ID}_{MODEL_NAME}",
    models_dir=config.MODELS_DIR
)
# Out:
# Model saved to: ./models/model_6_augmented_cnn.keras

# %%
# Save the confusion matrix to a file
confusion_matrix_path = (
    f"{config.CONFUSION_DIR}/model_{MODEL_ID}_{MODEL_NAME}_confusion_matrix.png"
)

save_confusion_matrix(
    test_labels=test_labels,
    test_predictions=test_predictions,
    output_path=confusion_matrix_path,
    title=f"Model {MODEL_ID} - Baseline CNN Confusion Matrix on CIFAR-10 Test Set"
)
# Out:
# './results/confusion_matrices/model_6_augmented_cnn_confusion_matrix.png'

# %%
experiment = {
    "model_id": MODEL_ID,
    "model_name": MODEL_NAME,
    "architecture": "DataAugmentation + Conv-Conv-Pool x2 + BatchNorm + Dense(64) + Dropout(0.5)",
    "optimizer": "Adam",
    "learning_rate": config.LEARNING_RATE,
    "batch_size": config.BATCH_SIZE,
    "epochs": len(history.history["accuracy"]),
    "train_accuracy": history.history["accuracy"][-1],
    "validation_accuracy": history.history["val_accuracy"][-1],
    "test_accuracy": test_accuracy,
    "precision": precision,
    "recall": recall,
    "train_loss": history.history["loss"][-1],
    "validation_loss": history.history["val_loss"][-1],
    "test_loss": test_loss,
    "train_time_seconds": train_time,
    "model_path": model_path,
    "confusion_matrix_path": confusion_matrix_path,
    "notes": "Model 6 tests whether data augmentation improves generalization"
    }

results_df = save_experiment_results(
    experiment,
    config.RESULTS_PATH
)

results_df
# Out:
#    model_id          model_name  \
# 0         1        baseline_cnn
# 1         2          deeper_cnn
# 2         3         dropout_cnn
# 3         4  adam_optimizer_cnn
# 4         5       batchnorm_cnn
# 5         6       augmented_cnn
#
#                                         architecture augmentation  \
# 0  Conv2D(32) + MaxPool + Conv2D(64) + MaxPool + ...           No
# 1  Conv2D(32) + Conv2D(32) + MaxPool + Conv2D(64)...          NaN
# 2       Conv-Conv-Pool x2 + Dense(64) + Dropout(0.5)          NaN
# 3       Conv-Conv-Pool x2 + Dense(64) + Dropout(0.5)          NaN
# 4  Conv-Conv-Pool x2 + BatchNorm + Dense(64) + Dr...          NaN
# 5  DataAugmentation + Conv-Conv-Pool x2 + BatchNo...          NaN
#
#   transfer_learning optimizer  learning_rate  batch_size  epochs  \
# 0                No       SGD          0.001          64      20
# 1               NaN       SGD          0.001          64      20
# 2               NaN       SGD          0.001          64      20
# 3               NaN      Adam          0.001          64      20
# 4               NaN      Adam          0.001          64      20
# 5               NaN      Adam          0.001          64      20
#
#    train_accuracy  ...  test_accuracy  train_loss  validation_loss  test_loss  \
# 0        0.379071  ...       0.371000    1.782614         1.779500   1.782990
# 1        0.397976  ...       0.323333    1.692275         1.718160   2.002619
# 2        0.274357  ...       0.293556    1.979604         1.973125   1.963245
# 3        0.757143  ...       0.734111    0.668025         0.831188   0.797122
# 4        0.904619  ...       0.748667    0.269671         0.963605   0.937387
# 5        0.743905  ...       0.743000    0.751405         0.766181   0.765216
#
#                                   model_path  \
# 0                  models/baseline_cnn.keras
# 1          ./models/model_2_deeper_cnn.keras
# 2         ./models/model_3_dropout_cnn.keras
# 3  ./models/model_4_adam_optimizer_cnn.keras
# 4       ./models/model_5_batchnorm_cnn.keras
# 5       ./models/model_6_augmented_cnn.keras
#
#                                confusion_matrix_path  \
# 0  results/confusion_matrices/model_1_baseline_cn...
# 1  ./results/confusion_matrices/model_2_deeper_cn...
# 2  ./results/confusion_matrices/model_3_dropout_c...
# 3  ./results/confusion_matrices/model_4_adam_opti...
# 4  ./results/confusion_matrices/model_5_batchnorm...
# 5  ./results/confusion_matrices/model_6_augmented...
#
#                                                notes precision    recall  \
# 0  Baseline CNN trained from scratch using SGD op...       NaN       NaN
# 1  Model 2 tests whether deeper Conv-Conv-Pool bl...  0.419784  0.323333
# 2  Model 3 tests whether Dropout reduces overfitt...  0.301318  0.293556
# 3  Model 4 tests optimizer effect by changing fro...  0.737549  0.734111
# 4  Model 5 tests whether Batch Normalization impr...  0.753583  0.748667
# 5  Model 6 tests whether data augmentation improv...  0.744561  0.743000
#
#    train_time_seconds
# 0                 NaN
# 1                80.3
# 2                80.8
# 3                88.2
# 4               102.7
# 5               241.0
#
# [6 rows x 21 columns]

# %%
# draw a plot of the training and validation accuracy over epochs
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Save the plot of the training and validation accuracy over epochs
os.makedirs(config.PLOTS_DIR, exist_ok=True)
accuracy_curves_path = (f"{config.PLOTS_DIR}/Model_{MODEL_ID}_{MODEL_NAME}_accuracy_curves.png")
plt.savefig(accuracy_curves_path, bbox_inches="tight")
plt.show()

print("Accuracy curves saved to:", accuracy_curves_path)
# Out:
# Accuracy curves saved to: ./results/plots/Model_6_augmented_cnn_accuracy_curves.png

# %%
# Draw the training and validation loss over epochs
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')    
plt.ylabel('Loss')
plt.legend()

# Save the plot of the training and validation loss over epochs
os.makedirs(config.PLOTS_DIR, exist_ok=True)
loss_curves_path = (f"{config.PLOTS_DIR}/Model_{MODEL_ID}_{MODEL_NAME}_loss_curves.png")
plt.savefig(loss_curves_path, bbox_inches="tight")
plt.show()

print("Loss curves saved to:", loss_curves_path)
# Out:
# Loss curves saved to: ./results/plots/Model_6_augmented_cnn_loss_curves.png

# %%
# Deploy the model using Gradio interface
# %cd /content/cifar10-cnn-classification-project
# !PYTHONPATH=/content/cifar10-cnn-classification-project python deployment/app.py
# Out:
# /content/cifar10-cnn-classification-project
# Traceback (most recent call last):
#   File "/content/cifar10-cnn-classification-project/deployment/app.py", line 12, in <module>
#     model = load_trained_model(MODEL_PATH)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/cifar10-cnn-classification-project/src/training/predictor.py", line 9, in load_trained_model
#     model = load_model(model_path)
#             ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_api.py", line 203, in load_model
#     raise ValueError(
# ValueError: File not found: filepath=/content/cifar10-cnn-classification-project/models/model_1_baseline_cnn.keras. Please ensure the file is an accessible `.keras` zip file.
